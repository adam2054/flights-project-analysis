# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Setze die maximale Anzahl der anzuzeigenden Zeilen
pd.set_option('display.max_rows', 100)  # Beispiel: Zeige bis zu 100 Zeilen

# Setze die maximale Anzahl der anzuzeigenden Spalten
pd.set_option('display.max_columns', 50)  # Beispiel: Zeige bis zu 50 Spalten

# Für eine breitere Darstellung jeder Zeile (um das Abschneiden von Daten zu vermeiden)
pd.set_option('display.max_colwidth', None)  # Oder verwenden Sie eine spezifische Zahl

# %%
#Neuer Datensatz zum Analysieren:
import ssl
 
ssl._create_default_https_context = ssl._create_unverified_context
import seaborn as sns
df_flights = sns.load_dataset('flights')

# %% [markdown]
# # **# # # Data 🗂️
# **Beschreibung der Spalten:
# # Spalte 'year' (Jahr):
#
# Die Spalte 'year' enthält Informationen über das Jahr, zu dem die Flugdaten gehören.
# Verschiedene Jahre sind in der Spalte 'year' enthalten: 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959 und 1960.
# Es scheint sich um eine diskrete numerische Spalte zu handeln, die die Jahre der Flugdaten darstellt.
# # Spalte 'month' (Monat):
#
# Die Spalte 'month' enthält die Namen der Monate, zu denen die Flugdaten gehören.
# Die verschiedenen Monate sind 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov' und 'Dec'.
# Dies ist eine kategorische Spalte, die die Monate des Jahres repräsentiert.
# Spalte 'passengers' (Passagiere):
#
# # Die Spalte 'passengers' enthält Informationen über die Anzahl der Passagiere für die entsprechenden Flugdaten.
# Es gibt eine Vielzahl von verschiedenen Werten, die die Anzahl der Passagiere pro Flug repräsentieren.
# Die Werte reichen von niedrigen Passagierzahlen wie 104 bis hin zu deutlich höheren Zahlen wie 622 und 646.
# Dies scheint eine numerische Spalte zu sein, die die Anzahl der Passagiere für verschiedene Flüge darstellt.

# %% [markdown]
# Description of Columns:
# 1. Column 'year' (Year):
# ◦	The 'year' column contains information about the year to which the flight data belongs.
# ◦	Various years included in the 'year' column are: 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, and 1960.
# ◦	It appears to be a discrete numerical column representing the years of the flight data.
# 2. Column 'month' (Month):
# ◦	The 'month' column contains the names of the months to which the flight data belongs.
# ◦	The different months are 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', and 'Dec'.
# ◦	This is a categorical column representing the months of the year.
# 3. Column 'passengers' (Passengers):
# ◦	The 'passengers' column contains information about the number of passengers for the respective flight data.
# ◦	There is a variety of different values representing the number of passengers per flight.
# ◦	The values range from lower passenger counts like 104 to significantly higher numbers such as 622 and 646.
# This appears to be a numerical column representing the count of passengers for different flights.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Project Overview 🚀
# Analysis of Passenger Evolution from 1949 to 1960
# # The dataset spans the years from 1949 to 1960 and provides insights into the evolving patterns of passenger numbers across these years. By analyzing the data, it's evident that the number of passengers fluctuates over time, showing an increasing trend from 1949 to 1960.
# **Yearly Evolution of Passengers:
# Over the years, there is a clear rising trend in the total number of passengers. In the initial year of 1949, the passenger count started at 148 passengers.
# With subsequent years, there's a noticeable increase, with 1960 showcasing the highest overall passenger count, reaching 622 passengers.**
# # Data Exploration 🔍
#
# # Monthly Patterns and Peak Travel Periods:
#
# Analyzing the data on a monthly basis, it's apparent that certain months consistently record higher passenger counts, particularly during the summer months of June, July, and August.
# July stands out prominently, consistently hosting the maximum number of passengers across most years. This surge in passengers during July aligns with favorable weather conditions and school vacations, indicating a probable correlation between high travel demand and school holidays.
# # Yearly Variations and Seasonal Influence:
#
# Within each year, there's a discernible trend of an upsurge in passenger numbers during the summer season. This suggests a preference for travel during warmer months, possibly driven by a desire for leisure or vacationing.
# Notably, the year 1960 exhibits a significant increase in passenger numbers for every month compared to previous years, indicating a surge in travel demand and heightened interest in summer travel during that year.
#
#
# # Conclusion 🏁
#
# The comparison between the first recorded year in 1949 and the peak year in 1960 illustrates a remarkable increase in travel demand, highlighting # an approximate 320% growth in passenger numbers over the analyzed period.

# %%
df_flights .to_csv('fleights.csv')

# %%
df_flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df_flights['year']=df_flights['year'].astype('category')
# Integer/Number: Years can often be stored as integers or numbers, particularly when the year value is a whole number and doesn't require any specific date or time information. 
# For example, in SQL databases, the INT datatype can be used to store years.
#+++++++++++++
# Date/DateTime: Sometimes, the year might be part of a date or timestamp, and in such cases, the datatype used could be a date or datetime type.
# For instance, in SQL, the DATE datatype might include both the year, month, and day.
# #++++++++++
# String/Character: In certain situations, years could be stored as strings or characters, 
# especially if the year might include non-numeric characters or needs to be stored in a specific format.

# %%
df_flights.year.unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960])

# %%
df_flights.month.unique()
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', ..., 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# Length: 12
# Categories (12, object): ['Jan', 'Feb', 'Mar', 'Apr', ..., 'Sep', 'Oct', 'Nov', 'Dec']

# %%
df_flights['passengers'].describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers, dtype: float64

# %%
df_flights.isna().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
df_flights.duplicated().sum()
# Out:
# 0

# %%
df_flights.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %% [markdown]
# 1. Distribution of passenger numbers over the months:

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='month', y='passengers', data=df_flights)
plt.title('Verteilung der Passagierzahlen über die Monate')
plt.xlabel('Monat')
plt.ylabel('Passagiere')
plt.show()

# %% [markdown]
# 2. Development of passenger numbers over the years:

# %%
plt.figure(figsize=(10, 7))
sns.lineplot(x='year', y='passengers', data=df_flights)
plt.title('2. Development of passenger numbers over the years:')
plt.xlabel('year')
plt.ylabel('passengers')
plt.show()

# %%
df_flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
# Create pivot table to put the data into the format required for the heatmap

pivot_passengers = df_flights.pivot_table(values='passengers', index='month', columns='year')
pivot_passengers
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %% [markdown]
# 3. Heatmap of passenger numbers per month and year:

# %%
#  Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_passengers, cmap='YlGnBu', annot=True, fmt='.1f')
plt.title('Heatmap of the total passenger numbers per month per year')
plt.xlabel('Year')
plt.ylabel('Month')
plt.show()

# %% [markdown]
# Passenger counts for the years 1949 and 1960

# %%
# Passenger counts for the years 1949 and 1960
passengers_1949 = 148  # Assume 148 passengers forjan in the year 1949 (as mentioned)
passengers_1960 = 622  # Passengers for the peak year 1960 (as mentioned)

# Calculate percentage increase
percentage_increase = ((passengers_1960 - passengers_1949) / passengers_1949) * 100

# Data for the bar plot
years = ['1949', '1960']
passenger_counts = [passengers_1949, passengers_1960]

# Create a bar plot to visualize the growth
plt.figure(figsize=(8, 6))
plt.bar(years, passenger_counts, color=['blue', 'orange'])
plt.ylabel('Passenger Counts')
plt.title('320% Growth in Passenger Numbers (Jan-1949 to Dec-1960)')
plt.text(0, passengers_1949 + 10, f'{passengers_1949}', ha='center')
plt.text(1, passengers_1960 + 10, f'{passengers_1960}\n+{percentage_increase:.0f}%', ha='center')
plt.ylim(0, passengers_1960 + 50)  # Adjust y-axis limit for better visualization
plt.show()
